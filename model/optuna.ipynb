# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings, os, sys, shutil
import xgboost as xgb
import lightgbm as lgb
import optuna
from catboost import CatBoost, CatBoostClassifier
from typing import Tuple
from utility import *
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score, log_loss

warnings.filterwarnings("ignore")

# %%
train = pd.read_csv('../preprocessed/combined_features_256.csv')
train = shuffle(train, random_state=42)
train.head()
# Out:
#       center_0_real  center_0_imag  center_1_real  center_1_imag  \
# 8756       0.684971       0.684896      -0.678801      -0.678806
# 4660      -0.686052      -0.685979       0.692808       0.692833
# 6095       0.684879       0.684834      -0.697076      -0.697706
# 304       -0.701005      -0.701018       0.706231       0.706214
# 8241      -0.696289      -0.696402       0.686460       0.686404
#
#       center_2_real  center_2_imag  center_3_real  center_3_imag    mean_i  \
# 8756      -0.706127       0.705716      -0.695909      -0.695835 -0.240262
# 4660      -0.705690       0.706469       0.704746      -0.705361 -0.271577
# 6095      -0.705148       0.705929       0.705620      -0.706525  0.560786
# 304       -0.702450       0.707012       0.707062      -0.702382 -0.470135
# 8241      -0.705922       0.704163      -0.679434      -0.679478 -0.219297
#
#         mean_q   std_dev  phase_consistency   entropy  skewness  kurtosis  \
# 8756 -0.229244  0.013307           1.503176  8.000000  0.750905  1.564859
# 4660 -0.254963  0.013975           1.503887  8.000000  0.868453  1.755275
# 6095  0.566200  0.014042           0.872788  8.000000 -2.866266  9.222158
# 304  -0.470149  0.002911           1.201315  7.960938  1.814242  4.291488
# 8241 -0.213853  0.013941           1.503746  8.000000  0.676113  1.458163
#
#       center_distance_std  cluster_counts_std  label
# 8756             0.311617           43.330128      2
# 4660             0.344874           70.770757      1
# 6095             0.452918           96.682470      1
# 304              0.491674           86.844689      0
# 8241             0.290996           40.155946      2

# %%
labels = train['label']
features = train.drop('label', axis=1)
features_col = features.columns

# %%
# 数据集分割
x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# %% [markdown]
# # 正式的KFold交叉验证 + Optuna模型调参

# %%
import optuna, tune

from optuna.samplers import TPESampler
from optuna.visualization import plot_contour
from optuna.visualization import plot_edf
from optuna.visualization import plot_intermediate_values
from optuna.visualization import plot_optimization_history
from optuna.visualization import plot_parallel_coordinate
from optuna.visualization import plot_param_importances
from optuna.visualization import plot_slice

from sklearn.model_selection import GridSearchCV, cross_val_score, cross_validate
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, log_loss
from sklearn.metrics import make_scorer, accuracy_score, log_loss
from sklearn.model_selection import ShuffleSplit, StratifiedShuffleSplit

# fold
from sklearn.model_selection import KFold, StratifiedKFold

# %% [markdown]
# without boost
# Number of finished trials: 500
# Best trial:
#   Value: 0.9753125
#   Params:
#     lambda: 0.5634396819975385
#     alpha: 7.214394029936068e-08
#     subsample: 0.37357930763967645
#     colsample_bytree: 0.2930407868220849
#     learning_rate: 0.010006143053735522
#     n_estimators: 4509
#
# with boost

# %%
def objective(trial):
    # dtrain = xgb.DMatrix(train, label=ytrain['Class'])
    '''

    '''
    param = {
        "verbosity": 0,
        "objective": "binary:logistic",
        "booster": trial.suggest_categorical("booster", ["gbtree", "gblinear", "dart"]),
        "lambda": trial.suggest_float("lambda", 1e-8, 1.0, log=True),
        "alpha": trial.suggest_float("alpha", 1e-8, 1.0, log=True),
        "subsample": trial.suggest_float("subsample", 0.2, 0.8),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.2, 0.8),
        'random_state' : 42,
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "n_estimators": trial.suggest_int("n_estimators", 300, 1000),
        # "early_stopping_rounds": trial.suggest_int("early_stopping_rounds", 100, 300),
    }

    if param["booster"] == "gbtree" or param["booster"] == "dart":
        param["max_depth"] = trial.suggest_int("max_depth", 1, 16)
        param["eta"] = trial.suggest_float("eta", 1e-3, 1.0, log=True)
        param["gamma"] = trial.suggest_float("gamma", 1e-8, 1.0, log=True)
        param["grow_policy"] = trial.suggest_categorical("grow_policy", ["depthwise", "lossguide"])
    if param["booster"] == "dart":
        param["sample_type"] = trial.suggest_categorical("sample_type", ["uniform", "weighted"])
        param["normalize_type"] = trial.suggest_categorical("normalize_type", ["tree", "forest"])
        param["rate_drop"] = trial.suggest_float("rate_drop", 1e-8, 1.0, log=True)
        param["skip_drop"] = trial.suggest_float("skip_drop", 1e-8, 1.0, log=True)

    xgb1 = xgb.XGBClassifier(**param)
    xgb1.fit(x_train, y_train)
    y_pred = xgb1.predict(x_test)
    return accuracy_score(y_test, y_pred)

    # # 交叉验证
    # skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    # log_loss_scores = []

    # # 划分验证集
    # for train_index, val_index in skf.split(x_train, y_train):
    #     x_train_, x_val = x_train.iloc[train_index], x_train.iloc[val_index]
    #     y_train_, y_val = y_train.iloc[train_index], y_train.iloc[val_index]
    #     classifier = xgb.XGBClassifier(**param)
    #     classifier.fit(x_train_, y_train_, eval_set=[(x_val, y_val)], verbose=False, early_stopping_rounds=200)
    #     y_pred = classifier.predict(x_val)
    #     acc = accuracy_score(y_val, y_pred)
    #     # y_pred_proba = classifier.predict_proba(x_val)[:, 1]
    #     log_loss_scores.append(acc)
    # return np.mean(acc)

if __name__ == "__main__":
    sampler = TPESampler(seed=42)
    pruner = optuna.pruners.MedianPruner(n_warmup_steps=10)
    study = optuna.create_study(pruner=pruner, direction="maximize", sampler=sampler)
    study.optimize(objective, n_trials=120)

    print("Number of finished trials: {}".format(len(study.trials)))
    print("Best trial:")
    trial = study.best_trial
    print("  Value: {}".format(trial.value))
    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))
# Out:
# [I 2024-04-21 09:58:08,577] A new study created in memory with name: no-name-acc3a114-a3cc-4bd1-aa15-0a13895736ca
# [I 2024-04-21 09:58:10,808] Trial 0 finished with value: 0.716875 and parameters: {'booster': 'gblinear', 'lambda': 0.0006155564318973012, 'alpha': 1.77071686435378e-07, 'subsample': 0.2935967122017216, 'colsample_bytree': 0.23485016730091968, 'learning_rate': 0.2611910822747312, 'n_estimators': 721}. Best is trial 0 with value: 0.716875.
# [I 2024-04-21 10:02:12,755] Trial 1 finished with value: 0.9703125 and parameters: {'booster': 'dart', 'lambda': 0.04566054873446119, 'alpha': 4.997040685255803e-07, 'subsample': 0.3090949803242604, 'colsample_bytree': 0.3100427059120603, 'learning_rate': 0.09823025045826593, 'n_estimators': 667, 'max_depth': 7, 'eta': 0.007476312062252299, 'gamma': 0.000784915956255507, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 0.00012997969313168238, 'skip_drop': 0.0005486767416600901}. Best is trial 1 with value: 0.9703125.
# [I 2024-04-21 10:02:13,457] Trial 2 finished with value: 0.2353125 and parameters: {'booster': 'gblinear', 'lambda': 3.3144597077512234e-08, 'alpha': 0.39001768308022033, 'subsample': 0.7793792198447358, 'colsample_bytree': 0.6850384088698768, 'learning_rate': 0.09833799306027749, 'n_estimators': 368}. Best is trial 1 with value: 0.9703125.
# [I 2024-04-21 10:02:20,287] Trial 3 finished with value: 0.96875 and parameters: {'booster': 'gbtree', 'lambda': 9.149877525022172e-05, 'alpha': 1.8841183049085085e-08, 'subsample': 0.7455922412472693, 'colsample_bytree': 0.3552679889600102, 'learning_rate': 0.20213146246265476, 'n_estimators': 518, 'max_depth': 9, 'eta': 0.043664735929796326, 'gamma': 3.0118659882617117e-07, 'grow_policy': 'depthwise'}. Best is trial 1 with value:
 'grow_policy': 'lossguide'}. Best is trial 8 with value: 0.9721875.
# [I 2024-04-21 10:38:41,066] Trial 54 finished with value: 0.9709375 and parameters: {'booster': 'gbtree', 'lambda': 0.03737636694461864, 'alpha': 7.4403202942005595e-06, 'subsample': 0.2383057279341653, 'colsample_bytree': 0.3930905094515328, 'learning_rate': 0.022523348636405104, 'n_estimators': 383, 'max_depth': 16, 'eta': 0.7661015010700024, 'gamma': 0.37450298832095363, 'grow_policy': 'lossguide'}. Best is trial 8 with value: 0.9721875.
# [I 2024-04-21 10:38:47,227] Trial 55 finished with value: 0.9690625 and parameters: {'booster': 'gbtree', 'lambda': 0.016776060415883826, 'alpha': 1.4317721839564748e-05, 'subsample': 0.2227275756094928, 'colsample_bytree': 0.42946689101480495, 'learning_rate': 0.062055238848946405, 'n_estimators': 417, 'max_depth': 10, 'eta': 0.11584328389342954, 'gamma': 0.07576636898942914, 'grow_policy': 'lossguide'}. Best is trial 8 with value: 0.9721875.
# [I 2024-04-21 10:38:57,052] Trial 56 finished with value: 0.9725 and parameters: {'booster': 'gbtree', 'lambda': 0.09478641125415958, 'alpha': 4.9790986705477784e-05, 'subsample': 0.32872490792691517, 'colsample_bytree': 0.4728459505858894, 'learning_rate': 0.031814879002306846, 'n_estimators': 536, 'max_depth': 13, 'eta': 0.32581350885007776, 'gamma': 0.008927280815148089, 'grow_policy': 'depthwise'}. Best is trial 56 with value: 0.9725.
# [I 2024-04-21 10:39:09,674] Trial 57 finished with value: 0.970625 and parameters: {'booster': 'gbtree', 'lambda': 0.38369083972246887, 'alpha': 7.189935766529623e-07, 'subsample': 0.3292211710132076, 'colsample_bytree': 0.47134109841366817, 'learning_rate': 0.010280188447106525, 'n_estimators': 535, 'max_depth': 15, 'eta': 0.6787260760378222, 'gamma': 0.010753263109012569, 'grow_policy': 'depthwise'}. Best is trial 56 with value: 0.9725.
# [I 2024-04-21 10:48:05,352] Trial 58 finished with value: 0.9690625 and parameters: {'booster': 'dart', 'lambda': 0.16615275409637031, 'alpha': 2.6065917398600404e-08, 'subsample': 0.2595700038061202, 'colsample_bytree': 0.5090087826261155, 'learning_rate': 0.029089804722138107, 'n_estimators': 918, 'max_depth': 14, 'eta': 0.44343909956389854, 'gamma': 0.001727034980296574, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 0.006265506026903481, 'skip_drop': 0.0032280947535526985}. Best is trial 56 with value: 0.9725.
# [I 2024-04-21 10:48:17,862] Trial 59 finished with value: 0.9678125 and parameters: {'booster': 'gbtree', 'lambda': 0.09917421913415084, 'alpha': 2.87220839545579e-06, 'subsample': 0.2944754398318924, 'colsample_bytree': 0.3553099928149142, 'learning_rate': 0.05204049388827378, 'n_estimators': 983, 'max_depth': 11, 'eta': 0.3350675433842431, 'gamma': 0.007209088916098104, 'grow_policy': 'depthwise'}. Best is trial 56 with value: 0.9725.
# [I 2024-04-21 10:48:20,840] Trial 60 finished with value: 0.6959375 and parameters: {'booster': 'gblinear', 'lambda': 0.05369137698461398, 'alpha': 5.7784901121461535e-05, 'subsample': 0.3373782691835614, 'colsample_bytree': 0.49128719825084644, 'learning_rate': 0.019547197027948417, 'n_estimators': 935}. Best is trial 56 with value: 0.9725.
# [I 2024-04-21 10:48:30,225] Trial 61 finished with value: 0.969375 and parameters: {'booster': 'gbtree', 'lambda': 0.013336701827181528, 'alpha': 1.8834114335799525e-05, 'subsample': 0.21440717891504113, 'colsample_bytree': 0.436191928929065, 'learning_rate': 0.037458649351614, 'n_estimators': 602, 'max_depth': 13, 'eta': 0.23436970392309542, 'gamma': 0.023561735731739336, 'grow_policy': 'depthwise'}. Best is trial 56 with value: 0.9725.
# [I 2024-04-21 10:48:39,137] Trial 62 finished with value: 0.97 and parameters: {'booster': 'gbtree', 'lambda': 0.0033491201606534165, 'alpha': 3.932386010888567e-05, 'subsample': 0.2713622794602578, 'colsample_bytree': 0.3992977229837369, 'learning_rate': 0.033670090425897595, 'n_estimators': 476, 'max_depth': 12, 'eta': 0.4058172444215257, 'gamma': 0.41650815469793045, 'grow_policy': 'depthwise'}. Best is trial 56 with value: 0.9725.
# [I 2024-04-21 10:48:46,413] Trial 63 finished with value: 0.9703125 and parameters: {'booster': 'gbtree', 'lambda': 0.010000880011002666, 'alpha': 8.279168813666125e-06, 'subsample': 0.30280433170229293, 'colsample_bytree': 0.45132646697677625, 'learning_rate': 0.04726424256955355, 'n_estimators': 419, 'max_depth': 14, 'eta': 0.3184677812150354, 'gamma': 0.047296608413029864, 'grow_policy': 'depthwise'}. Best is trial 56 with value: 0.9725.
# [I 2024-04-21 10:48:48,751] Trial 64 finished with value: 0.93625 and parameters: {'booster': 'gbtree', 'lambda': 0.0332249718777353, 'alpha': 0.0001060482094918388, 'subsample': 0.25196197718838914, 'colsample_bytree': 0.41619671226170957, 'learning_rate': 0.06980365684419435, 'n_estimators': 462, 'max_depth': 1, 'eta': 0.9068169322011297, 'gamma': 0.13399111679347614, 'grow_policy': 'depthwise'}. Best is trial 56 with value: 0.9725.
# [I 2024-04-21 10:48:56,212] Trial 65 finished with value: 0.97 and parameters: {'booster': 'gbtree', 'lambda': 0.007284562201267025, 'alpha': 1.7235355928719105e-05, 'subsample': 0.22815546629322417, 'colsample_bytree': 0.3858862601644479, 'learning_rate': 0.07793621765320083, 'n_estimators': 537, 'max_depth': 12, 'eta': 0.5713753425636967, 'gamma': 0.023862384082191414, 'grow_policy': 'depthwise'}. Best is trial 56 with value: 0.9725.
# [I 2024-04-21 10:49:08,020] Trial 66 finished with value: 0.9715625 and parameters: {'booster': 'gbtree', 'lambda': 0.0020020509173745583, 'alpha': 2.381689886780225e-05, 'subsample': 0.22124215277944326, 'colsample_bytree': 0.4749267997714123, 'learning_rate': 0.05543316258447147, 'n_estimators': 972, 'max_depth': 16, 'eta': 0.1642220253793355, 'gamma': 0.003757911937419277, 'grow_policy': 'lossguide'}. Best is trial 56 with value: 0.9725.
# [I 2024-04-21 10:49:11,019] Trial 67 finished with value: 0.9459375 and parameters: {'booster': 'gbtree', 'lambda': 0.022575884001590052, 'alpha': 0.0005961361564527876, 'subsample': 0.24998478009792466, 'colsample_bytree': 0.4478722147603766, 'learning_rate': 0.02833340556411837, 'n_estimators': 335, 'max_depth': 3, 'eta': 0.2617031210733198, 'gamma': 0.5255351879317377, 'grow_policy': 'depthwise'}. Best is trial 56 with value: 0.9725.
# [I 2024-04-21 10:49:24,107] Trial 68 finished with value: 0.973125 and parameters: {'booster': 'gbtree', 'lambda': 0.0008011157411202396, 'alpha': 4.2183104240512996e-07, 'subsample': 0.3107421070088247, 'colsample_bytree': 0.5003767989031228, 'learning_rate': 0.01783311021926046, 'n_estimators': 508, 'max_depth': 14, 'eta': 0.09200367777304776, 'gamma': 0.156623530903035, 'grow_policy': 'depthwise'}. Best is trial 68 with value: 0.973125.
# [I 2024-04-21 10:49:40,077] Trial 69 finished with value: 0.9728125 and parameters: {'booster': 'gbtree', 'lambda': 0.0007840132241279272, 'alpha': 7.94127626683728e-08, 'subsample': 0.3135911730603464, 'colsample_bytree': 0.5034696739063358, 'learning_rate': 0.010191084825943053, 'n_estimators': 662, 'max_depth': 14, 'eta': 0.10846898121098614, 'gamma': 0.1933079524799196, 'grow_policy': 'depthwise'}. Best is trial 68 with value: 0.973125.
# [I 2024-04-21 10:55:41,941] Trial 70 finished with value: 0.97375 and parameters: {'booster': 'dart', 'lambda': 0.000558856883302146, 'alpha': 7.452665534821873e-08, 'subsample': 0.3590872279947728, 'colsample_bytree': 0.5361114442502848, 'learning_rate': 0.019109976582779423, 'n_estimators': 746, 'max_depth': 15, 'eta': 0.08396356078815152, 'gamma': 0.1771719865632377, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 1.0769881872021106e-06, 'skip_drop': 5.1249783991907545e-06}. Best is trial 70 with value: 0.97375.
# [I 2024-04-21 11:00:38,926] Trial 71 finished with value: 0.9725 and parameters: {'booster': 'dart', 'lambda': 0.0005401264758231728, 'alpha': 8.143005272800617e-08, 'subsample': 0.365714071965526, 'colsample_bytree': 0.5329840719342197, 'learning_rate': 0.01061094619747456, 'n_estimators': 674, 'max_depth': 15, 'eta': 0.08321172997348529, 'gamma': 0.19115313458305236, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 1.3019403248597962e-06, 'skip_drop': 4.372588231955141e-06}. Best is trial 70 with value: 0.97375.
# [I 2024-04-21 11:06:54,402] Trial 72 finished with value: 0.971875 and parameters: {'booster': 'dart', 'lambda': 0.0005232137142597692, 'alpha': 1.336412493807334e-07, 'subsample': 0.36096666559353857, 'colsample_bytree': 0.541207801559246, 'learning_rate': 0.021039707575797796, 'n_estimators': 766, 'max_depth': 15, 'eta': 0.09160946256703553, 'gamma': 0.1782557747890843, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 3.038863651509331e-06, 'skip_drop': 3.0536323009879785e-06}. Best is trial 70 with value: 0.97375.
# [I 2024-04-21 11:11:33,850] Trial 73 finished with value: 0.9734375 and parameters: {'booster': 'dart', 'lambda': 0.00020559161283444915, 'alpha': 5.3176339173139e-08, 'subsample': 0.3527667265925571, 'colsample_bytree': 0.5585007480760784, 'learning_rate': 0.029519541898913964, 'n_estimators': 671, 'max_depth': 14, 'eta': 0.07150836685536241, 'gamma': 0.5963135101561317, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 1.2741706111725305e-06, 'skip_drop': 5.8092793659254555e-06}. Best is trial 70 with value: 0.97375.
# [I 2024-04-21 11:16:08,969] Trial 74 finished with value: 0.97375 and parameters: {'booster': 'dart', 'lambda': 0.0008545584634408113, 'alpha': 6.917775794279691e-08, 'subsample': 0.3805311301297172, 'colsample_bytree': 0.5301552451210866, 'learning_rate': 0.032230583019413075, 'n_estimators': 686, 'max_depth': 14, 'eta': 0.07180742082902308, 'gamma': 0.5499547780933273, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 1.5383119155948493e-06, 'skip_drop': 6.434265915881029e-06}. Best is trial 70 with value: 0.97375.
# [I 2024-04-21 11:20:28,800] Trial 75 finished with value: 0.9721875 and parameters: {'booster': 'dart', 'lambda': 0.00012930716983065673, 'alpha': 6.510245881827883e-08, 'subsample': 0.3813571187681112, 'colsample_bytree': 0.5504493724730044, 'learning_rate': 0.032860941190729846, 'n_estimators': 669, 'max_depth': 14, 'eta': 0.0710326931499937, 'gamma': 0.6152592110597128, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 8.700630589497088e-07, 'skip_drop': 6.057745417242254e-06}. Best is trial 70 with value: 0.97375.
# [I 2024-04-21 11:25:53,099] Trial 76 finished with value: 0.973125 and parameters: {'booster': 'dart', 'lambda': 0.0010360243590283756, 'alpha': 3.9357969402942477e-07, 'subsample': 0.3488484855029428, 'colsample_bytree': 0.5283763184743825, 'learning_rate': 0.017921195666828704, 'n_estimators': 731, 'max_depth': 14, 'eta': 0.05356781676756216, 'gamma': 0.16364063232924048, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 7.226947656989398e-07, 'skip_drop': 9.436953492965894e-06}. Best is trial 70 with value: 0.97375.
# [I 2024-04-21 11:31:12,067] Trial 77 finished with value: 0.9728125 and parameters: {'booster': 'dart', 'lambda': 0.0009768461346772704, 'alpha': 3.110407830629526e-07, 'subsample': 0.3693917322610975, 'colsample_bytree': 0.5057829837066385, 'learning_rate': 0.017876747064952597, 'n_estimators': 720, 'max_depth': 15, 'eta': 0.05660776295273816, 'gamma': 0.19532947445694324, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 8.778756823996692e-07, 'skip_drop': 9.284917398919392e-06}. Best is trial 70 with value: 0.97375.
# [I 2024-04-21 11:36:38,661] Trial 78 finished with value: 0.9709375 and parameters: {'booster': 'dart', 'lambda': 0.0009486292207002743, 'alpha': 2.3073000003936845e-07, 'subsample': 0.34602598351230535, 'colsample_bytree': 0.5043951168850535, 'learning_rate': 0.025635209801016273, 'n_estimators': 719, 'max_depth': 14, 'eta': 0.04772704755722673, 'gamma': 0.13115109598609648, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 4.260570395199081e-07, 'skip_drop': 2.037798500532848e-05}. Best is trial 70 with value: 0.97375.
# [I 2024-04-21 11:41:04,557] Trial 79 finished with value: 0.9721875 and parameters: {'booster': 'dart', 'lambda': 0.0001970095554093758, 'alpha': 3.604024093284243e-07, 'subsample': 0.31832248608400615, 'colsample_bytree': 0.5617956710931019, 'learning_rate': 0.016975396963540862, 'n_estimators': 646, 'max_depth': 14, 'eta': 0.055912393053356615, 'gamma': 0.6660399220663288, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 6.500645042479587e-06, 'skip_drop': 2.109739000733186e-05}. Best is trial 70 with value: 0.97375.
# [I 2024-04-21 11:46:19,143] Trial 80 finished with value: 0.97 and parameters: {'booster': 'dart', 'lambda': 0.0003562222246623056, 'alpha': 1.4897459487466296e-07, 'subsample': 0.40534734195786565, 'colsample_bytree': 0.5868680417139138, 'learning_rate': 0.04466348433452855, 'n_estimators': 737, 'max_depth': 6, 'eta': 0.0357598940389003, 'gamma': 0.35014649475943765, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 2.19448257053001e-07, 'skip_drop': 6.68613997132191e-07}. Best is trial 70 with value: 0.97375.
# [I 2024-04-21 11:51:23,048] Trial 81 finished with value: 0.9721875 and parameters: {'booster': 'dart', 'lambda': 0.0005877049114018513, 'alpha': 8.421926197593854e-08, 'subsample': 0.37438150216371396, 'colsample_bytree': 0.543398551821185, 'learning_rate': 0.01018381213590041, 'n_estimators': 686, 'max_depth': 15, 'eta': 0.09260134646241379, 'gamma': 0.20542426503776196, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 5.46414494881202e-07, 'skip_drop': 4.498205544817426e-06}. Best is trial 70 with value: 0.97375.
# [I 2024-04-21 11:55:26,884] Trial 82 finished with value: 0.9734375 and parameters: {'booster': 'dart', 'lambda': 0.001383144996317391, 'alpha': 3.624275876922489e-08, 'subsample': 0.3435725122520642, 'colsample_bytree': 0.5218374474181491, 'learning_rate': 0.03264583158501656, 'n_estimators': 619, 'max_depth': 15, 'eta': 0.06923074708592776, 'gamma': 0.09735734437629467, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 7.719770648325106e-06, 'skip_drop': 1.2824846764235752e-05}. Best is trial 70 with value: 0.97375.
# [I 2024-04-21 12:01:37,863] Trial 83 finished with value: 0.9740625 and parameters: {'booster': 'dart', 'lambda': 0.001363447562099711, 'alpha': 3.000892306330751e-08, 'subsample': 0.34561662153484923, 'colsample_bytree': 0.5221559170250554, 'learning_rate': 0.030747440786037243, 'n_estimators': 776, 'max_depth': 14, 'eta': 0.065052398581408, 'gamma': 0.09935871545859493, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 1.2677034032297492e-05, 'skip_drop': 2.964101536394903e-05}. Best is trial 83 with value: 0.9740625.
# [I 2024-04-21 12:07:53,600] Trial 84 finished with value: 0.9734375 and parameters: {'booster': 'dart', 'lambda': 0.0012703611574171475, 'alpha': 3.347985887387802e-08, 'subsample': 0.35203978717147205, 'colsample_bytree': 0.5236829990426246, 'learning_rate': 0.0228006559418988, 'n_estimators': 772, 'max_depth': 14, 'eta': 0.06413863778325056, 'gamma': 0.06676363763792205, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 1.1768796728838375e-05, 'skip_drop': 3.151770204151659e-05}. Best is trial 83 with value: 0.9740625.
# [I 2024-04-21 12:17:50,363] Trial 85 finished with value: 0.9734375 and parameters: {'booster': 'dart', 'lambda': 0.0015584257234841684, 'alpha': 2.897255865995304e-08, 'subsample': 0.34705003059829875, 'colsample_bytree': 0.5217928353364321, 'learning_rate': 0.02637442088636911, 'n_estimators': 805, 'max_depth': 14, 'eta': 0.06736219019862465, 'gamma': 0.08932791118812775, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 1.3792496214645528e-05, 'skip_drop': 3.9618971071565145e-05}. Best is trial 83 with value: 0.9740625.
# [I 2024-04-21 12:32:10,315] Trial 86 finished with value: 0.9715625 and parameters: {'booster': 'dart', 'lambda': 0.0015291501337834337, 'alpha': 1.0145368727554216e-08, 'subsample': 0.3524586315424243, 'colsample_bytree': 0.5290190565021082, 'learning_rate': 0.037431859601591115, 'n_estimators': 788, 'max_depth': 13, 'eta': 0.07245649536502574, 'gamma': 0.0826065233480063, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 6.650330164206414e-06, 'skip_drop': 4.1989997170683916e-05}. Best is trial 83 with value: 0.9740625.
# [I 2024-04-21 13:47:58,092] Trial 87 finished with value: 0.971875 and parameters: {'booster': 'dart', 'lambda': 0.001642503154410547, 'alpha': 2.8456229527881028e-08, 'subsample': 0.3431387440085293, 'colsample_bytree': 0.5217278257570154, 'learning_rate': 0.026933381156000847, 'n_estimators': 815, 'max_depth': 14, 'eta': 0.06455751355230073, 'gamma': 0.06478402966069816, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 1.0795037051330119e-05, 'skip_drop': 3.654340342849924e-05}. Best is trial 83 with value: 0.9740625.

# %%
plot_optimization_history(study)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plot_optimization_history(study)
#
# NameError: name 'study' is not defined

# %%
plot_intermediate_values(study)

# %%
plot_parallel_coordinate(study)

# %%
plot_contour(study)

# %%
plot_slice(study)

# %%
plot_param_importances(study)
